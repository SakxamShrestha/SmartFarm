# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('data.csv')

# Display the DataFrame to see the tabular form
print(df)
# Out:
#     Soil_Moisture  Temperature  Nutrient Levels  Acidity (pH)  Pest Activity  \
# 0              74           34                4      6.627958              8
# 1              54           21                5      7.217530              8
# 2              30           22                5      5.366114              9
# 3               3           13                3      6.755173              7
# 4              58           23                2      7.050809              7
# 5              97           36                1      7.957134              6
# 6              49           31                2      6.113473              5
# 7              72           26                3      5.890476             10
# 8              73           12                1      7.976710              7
# 9              26           39                0      4.789711              9
# 10             41           19                2      5.416454              3
# ...
